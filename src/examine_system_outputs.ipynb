# %%
import sys
import os
from IPython.display import Image, display, clear_output
sys.path.append(os.path.expanduser('~/graph-trend-understanding/network/'))
sys.path.append(os.path.expanduser('~/graph-trend-understanding/'))

# %%
OUTPUTS_FILE = os.path.expanduser('~/graph-trend-understanding/network/outputs_next_best.txt')

# %%
# read outputs file 
outputs = []

with open(OUTPUTS_FILE, 'r') as infile: 
    for line in infile: 
        #impath, actual_label, model_label = line.split(" ")
        outputs.append(line.split(" "))
        
len(outputs)
# Out:
# 527

# %%
def show_output(i): 
    clear_output()
    impath, actual_label, model_label = outputs[i]
    actual_label = int(actual_label) -1
    model_label = int(model_label) - 1
    img = Image(impath)
    #if actual_label is model_label: 
    if True:
    #if impath == '/home/ubuntu/graph-trend-understanding/data/test/scraped_nathan/line_chart_vega_200.jpg':
        print("path", impath)
        print("Actual label: %d" % actual_label)
        print("Model label: %d" % model_label)
        display(img)
        return True
    return False

# %%
counter = 0

# %%
counter -=2

# %%
while True:
    if show_output(counter): 
        counter += 1
        break
    counter += 1
# Out:
# path /home/ubuntu/graph-trend-understanding/data/test/scraped_nathan/line_chart_wsj_236.jpg
# Actual label: -1
# Model label: 0
